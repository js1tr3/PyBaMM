# %%
import pybamm
import numpy as np
import pickle
import matplotlib.pyplot as plt

pybamm.set_logging_level("INFO")

data_DIR = "../data/"
fig_DIR = "../figs/"

# %% [markdown]
# ## Charge Discharge 1 Cycle

# %%
spm_old = {}
with open(data_DIR +'spm_old_fresh_vars_Cb5.pickle', 'rb') as handle:
        spm_old[0] = pickle.load(handle)
with open(data_DIR +'spm_old_fresh_vars_1p5C.pickle', 'rb') as handle:
        spm_old[1] = pickle.load(handle)
with open(data_DIR +'spm_old_fresh_vars_2C.pickle', 'rb') as handle:
        spm_old[2] = pickle.load(handle)
spm_new = {}
with open(data_DIR +'spm_new_fresh_vars_Cb5.pickle', 'rb') as handle:
        spm_new[0] = pickle.load(handle)
with open(data_DIR +'spm_new_fresh_vars_1p5C.pickle', 'rb') as handle:
        spm_new[1] = pickle.load(handle)
with open(data_DIR +'spm_new_fresh_vars_2C.pickle', 'rb') as handle:
        spm_new[2] = pickle.load(handle)
dfn_old = {}
with open(data_DIR +'dfn_old_fresh_vars_Cb5.pickle', 'rb') as handle:
        dfn_old[0] = pickle.load(handle)
with open(data_DIR +'dfn_old_fresh_vars_1p5C.pickle', 'rb') as handle:
        dfn_old[1] = pickle.load(handle)
with open(data_DIR +'dfn_old_fresh_vars_2C.pickle', 'rb') as handle:
        dfn_old[2] = pickle.load(handle)
dfn_new = {}
with open(data_DIR +'dfn_new_fresh_vars_Cb5.pickle', 'rb') as handle:
        dfn_new[0] = pickle.load(handle)
with open(data_DIR +'dfn_new_fresh_vars_1p5C.pickle', 'rb') as handle:
        dfn_new[1] = pickle.load(handle)
with open(data_DIR +'dfn_new_fresh_vars_2C.pickle', 'rb') as handle:
        dfn_new[2] = pickle.load(handle)

# %%
fig, ax = plt.subplots(2,3,figsize=(15,8))
ax1 = ax.flat[0]
ax1.plot(spm_old[0][1],spm_old[0][2],'b')
ax1.plot(spm_new[0][1],spm_new[0][2],'r--')
ax1.set_xlabel("Time [h]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("C/5")
ax1.legend(["Old","New"])
ax2 = ax.flat[3]
ax2.plot(spm_old[0][1],spm_old[0][3],'b')
ax2.plot(spm_new[0][1],spm_new[0][3],'r--')
ax2.set_xlabel("Time [h]")
ax2.set_ylabel("Current [A]")

ax3 = ax.flat[1]
ax3.plot(spm_old[1][1],spm_old[1][2],'b')
ax3.plot(spm_new[1][1],spm_new[1][2],'r--')
ax3.set_xlabel("Time [h]")
ax3.set_ylabel("Voltage [V]")
ax3.set_title("1.5C")
ax4 = ax.flat[4]
ax4.plot(spm_old[1][1],spm_old[1][3],'b')
ax4.plot(spm_new[1][1],spm_new[1][3],'r--')
ax4.set_xlabel("Time [h]")
ax4.set_ylabel("Current [A]")

ax5 = ax.flat[2]
ax5.plot(spm_old[2][1],spm_old[2][2],'b')
ax5.plot(spm_new[2][1],spm_new[2][2],'r--')
ax5.set_xlabel("Time [h]")
ax5.set_ylabel("Voltage [V]")
ax5.set_title("2C")
ax6 = ax.flat[5]
ax6.plot(spm_old[2][1],spm_old[2][3],'b')
ax6.plot(spm_new[2][1],spm_new[2][3],'r--')
ax6.set_xlabel("Time [h]")
ax6.set_ylabel("Current [A]")

fig.suptitle("SPM Old vs New")
fig.tight_layout()
fig.savefig(fig_DIR+"spm_comp_multi.png",dpi=600)

# %%
fig, ax = plt.subplots(2,3,figsize=(15,8))
ax1 = ax.flat[0]
ax1.plot(dfn_old[0][1],dfn_old[0][2],'b')
ax1.plot(dfn_new[0][1],dfn_new[0][2],'r--')
ax1.set_xlabel("Time [h]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("C/5")
ax1.legend(["Old","New"])
ax2 = ax.flat[3]
ax2.plot(dfn_old[0][1],dfn_old[0][3],'b')
ax2.plot(dfn_new[0][1],dfn_new[0][3],'r--')
ax2.set_xlabel("Time [h]")
ax2.set_ylabel("Current [A]")

ax3 = ax.flat[1]
ax3.plot(dfn_old[1][1],dfn_old[1][2],'b')
ax3.plot(dfn_new[1][1],dfn_new[1][2],'r--')
ax3.set_xlabel("Time [h]")
ax3.set_ylabel("Voltage [V]")
ax3.set_title("1.5C")
ax4 = ax.flat[4]
ax4.plot(dfn_old[1][1],dfn_old[1][3],'b')
ax4.plot(dfn_new[1][1],dfn_new[1][3],'r--')
ax4.set_xlabel("Time [h]")
ax4.set_ylabel("Current [A]")

ax5 = ax.flat[2]
ax5.plot(dfn_old[2][1],dfn_old[2][2],'b')
ax5.plot(dfn_new[2][1],dfn_new[2][2],'r--')
ax5.set_xlabel("Time [h]")
ax5.set_ylabel("Voltage [V]")
ax5.set_title("2C")
ax6 = ax.flat[5]
ax6.plot(dfn_old[2][1],dfn_old[2][3],'b')
ax6.plot(dfn_new[2][1],dfn_new[2][3],'r--')
ax6.set_xlabel("Time [h]")
ax6.set_ylabel("Current [A]")

fig.suptitle("DFN Old vs New")
fig.tight_layout()
fig.savefig(fig_DIR+"dfn_comp_multi.png",dpi=600)

# %% [markdown]
# ### Surface Concentration

# %%
fig, ax = plt.subplots(2,3,figsize=(15,8))
ax1 = ax.flat[0]
ax1.plot(spm_old[0][1],spm_old[0][4],'b')
ax1.plot(spm_new[0][1],spm_new[0][4],'r--')
ax1.set_xlabel("Time [h]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("C/5")
ax1.legend(["Old","New"])
ax2 = ax.flat[3]
ax2.plot(spm_old[0][1],spm_old[0][4],'b')
ax2.plot(spm_new[0][1],spm_new[0][4],'r--')
ax2.set_xlabel("Time [h]")
ax2.set_ylabel("Current [A]")

ax3 = ax.flat[1]
ax3.plot(spm_old[1][1],spm_old[1][4],'b')
ax3.plot(spm_new[1][1],spm_new[1][4],'r--')
ax3.set_xlabel("Time [h]")
ax3.set_ylabel("Voltage [V]")
ax3.set_title("1.5C")
ax4 = ax.flat[4]
ax4.plot(spm_old[1][1],spm_old[1][3],'b')
ax4.plot(spm_new[1][1],spm_new[1][3],'r--')
ax4.set_xlabel("Time [h]")
ax4.set_ylabel("Current [A]")

ax5 = ax.flat[2]
ax5.plot(spm_old[2][1],spm_old[2][2],'b')
ax5.plot(spm_new[2][1],spm_new[2][2],'r--')
ax5.set_xlabel("Time [h]")
ax5.set_ylabel("Voltage [V]")
ax5.set_title("2C")
ax6 = ax.flat[5]
ax6.plot(spm_old[2][1],spm_old[2][3],'b')
ax6.plot(spm_new[2][1],spm_new[2][3],'r--')
ax6.set_xlabel("Time [h]")
ax6.set_ylabel("Current [A]")

fig.suptitle("SPM Old vs New")
fig.tight_layout()
fig.savefig(fig_DIR+"spm_comp_surfconc.png",dpi=600)

# %%
fig, ax = plt.subplots(2,3,figsize=(15,8))
ax1 = ax.flat[0]
ax1.plot(dfn_old[0][1],dfn_old[0][4],'b')
ax1.plot(dfn_new[0][1],dfn_new[0][4],'r--')
ax1.set_xlabel("Time [h]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("C/5")
ax1.legend(["Old","New"])
ax2 = ax.flat[3]
ax2.plot(dfn_old[0][1],dfn_old[0][4],'b')
ax2.plot(dfn_new[0][1],dfn_new[0][4],'r--')
ax2.set_xlabel("Time [h]")
ax2.set_ylabel("Current [A]")

ax3 = ax.flat[1]
ax3.plot(dfn_old[1][1],dfn_old[1][4],'b')
ax3.plot(dfn_new[1][1],dfn_new[1][4],'r--')
ax3.set_xlabel("Time [h]")
ax3.set_ylabel("Voltage [V]")
ax3.set_title("1.5C")
ax4 = ax.flat[4]
ax4.plot(dfn_old[1][1],dfn_old[1][3],'b')
ax4.plot(dfn_new[1][1],dfn_new[1][3],'r--')
ax4.set_xlabel("Time [h]")
ax4.set_ylabel("Current [A]")

ax5 = ax.flat[2]
ax5.plot(dfn_old[2][1],dfn_old[2][2],'b')
ax5.plot(dfn_new[2][1],dfn_new[2][2],'r--')
ax5.set_xlabel("Time [h]")
ax5.set_ylabel("Voltage [V]")
ax5.set_title("2C")
ax6 = ax.flat[5]
ax6.plot(dfn_old[2][1],dfn_old[2][3],'b')
ax6.plot(dfn_new[2][1],dfn_new[2][3],'r--')
ax6.set_xlabel("Time [h]")
ax6.set_ylabel("Current [A]")

fig.suptitle("DFN Old vs New")
fig.tight_layout()
fig.savefig(fig_DIR+"dfn_comp_surfconc.png",dpi=600)

# %%
sdfsdfsd

# %% [markdown]
# ## Voltage Components

# %%
with open(data_DIR +'spm_old_fresh_vars_pulse.pickle', 'rb') as handle:
        spm_old = pickle.load(handle)
with open(data_DIR +'spm_new_fresh_vars_pulse.pickle', 'rb') as handle:
        spm_new = pickle.load(handle)
with open(data_DIR +'dfn_old_fresh_vars_pulse.pickle', 'rb') as handle:
        dfn_old = pickle.load(handle)
with open(data_DIR +'dfn_new_fresh_vars_pulse.pickle', 'rb') as handle:
        dfn_new = pickle.load(handle)

# %%
fig, ax = plt.subplots(2,3,figsize=(15,8))
ax1 = ax.flat[0]
ax1.plot(spm_old[0],spm_old[12],'b')
ax1.plot(spm_new[0],spm_new[12],'r--')
ax1.set_xlim([50,100])
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("Reaction overpotential")
ax1.legend(["Old","New"])
ax2 = ax.flat[1]
ax2.plot(spm_old[0],spm_old[13],'b')
ax2.plot(spm_new[0],spm_new[13],'r--')
ax2.set_xlim([50,100])
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("Voltage [V]")
ax2.set_title("Concentration overpotential")
ax3 = ax.flat[2]
ax3.plot(spm_old[0],spm_old[14],'b')
ax3.plot(spm_new[0],spm_new[14],'r--')
ax3.set_xlim([50,100])
ax3.set_xlabel("Time [s]")
ax3.set_ylabel("Voltage [V]")
ax3.set_title("Ohmic electrolyte overpotential")
ax4 = ax.flat[3]
ax4.plot(spm_old[0],spm_old[15],'b')
ax4.plot(spm_new[0],spm_new[15],'r--')
ax4.set_xlim([50,100])
ax4.set_xlabel("Time [s]")
ax4.set_ylabel("Voltage [V]")
ax4.set_title("Ohmic electrode overpotential")
ax5 = ax.flat[5]
ax5.plot(spm_old[0],spm_old[16],'b')
ax5.plot(spm_new[0],spm_new[16],'r--')
ax5.set_xlim([50,100])
ax5.set_xlabel("Time [s]")
ax5.set_ylabel("Voltage [V]")
ax5.set_title("Battery open circuit voltage [V]")
fig.suptitle("SPM: Pulse at 50% SOC")
fig.tight_layout()
fig.savefig(fig_DIR+"spm_comp_pulse.png",dpi=600)

# %%
fig, ax = plt.subplots(2,1,figsize=(5,8))
ax1 = ax.flat[0]
ax1.plot(spm_old[0],spm_old[2],'b')
ax1.plot(spm_new[0],spm_new[2],'r--')
ax1.set_xlim([50,100])
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Voltage [V]")
ax2 = ax.flat[1]
ax2.plot(spm_old[0],spm_old[3],'b')
ax2.plot(spm_new[0],spm_new[3],'r--')
ax2.set_xlim([50,100])
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("Current [A]")

fig.suptitle("SPM Old vs New")
fig.tight_layout()
fig.savefig(fig_DIR+"spm_comp_pulseV.png",dpi=600)

# %%
fig, ax = plt.subplots(2,3,figsize=(15,8))
ax1 = ax.flat[0]
ax1.plot(dfn_old[0],dfn_old[12],'b')
ax1.plot(dfn_new[0],dfn_new[12],'r--')
ax1.set_xlim([50,100])
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("Reaction overpotential")
ax1.legend(["Old","New"])
ax2 = ax.flat[1]
ax2.plot(dfn_old[0],dfn_old[13],'b')
ax2.plot(dfn_new[0],dfn_new[13],'r--')
ax2.set_xlim([50,100])
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("Voltage [V]")
ax2.set_title("Concentration overpotential")
ax3 = ax.flat[2]
ax3.plot(dfn_old[0],dfn_old[14],'b')
ax3.plot(dfn_new[0],dfn_new[14],'r--')
ax3.set_xlim([50,100])
ax3.set_xlabel("Time [s]")
ax3.set_ylabel("Voltage [V]")
ax3.set_title("Ohmic electrolyte overpotential")
ax4 = ax.flat[3]
ax4.plot(dfn_old[0],dfn_old[15],'b')
ax4.plot(dfn_new[0],dfn_new[15],'r--')
ax4.set_xlim([50,100])
ax4.set_xlabel("Time [s]")
ax4.set_ylabel("Voltage [V]")
ax4.set_title("Ohmic electrode overpotential")
ax5 = ax.flat[5]
ax5.plot(dfn_old[0],dfn_old[16],'b')
ax5.plot(dfn_new[0],dfn_new[16],'r--')
ax5.set_xlim([50,100])
ax5.set_xlabel("Time [s]")
ax5.set_ylabel("Voltage [V]")
ax5.set_title("Battery open circuit voltage [V]")
fig.suptitle("DFN: Pulse at 50% SOC")
fig.tight_layout()
fig.savefig(fig_DIR+"dfn_comp_pulse.png",dpi=600)

# %%
fig, ax = plt.subplots(2,1,figsize=(5,8))
ax1 = ax.flat[0]
ax1.plot(dfn_old[0],dfn_old[2],'b')
ax1.plot(dfn_new[0],dfn_new[2],'r--')
ax1.set_xlim([50,100])
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Voltage [V]")
ax2 = ax.flat[1]
ax2.plot(dfn_old[0],dfn_old[3],'b')
ax2.plot(dfn_new[0],dfn_new[3],'r--')
ax2.set_xlim([50,100])
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("Current [A]")

fig.suptitle("DFN Old vs New")
fig.tight_layout()
fig.savefig(fig_DIR+"dfn_comp_pulseV.png",dpi=600)

# %% [markdown]
# ## SEI 1 Cycle

# %%
with open(data_DIR +'spm_old_sei_1cycle_vars_Cb5.pickle', 'rb') as handle:
        spm_old = pickle.load(handle)
with open(data_DIR +'spm_new_sei_1cycle_vars_Cb5.pickle', 'rb') as handle:
        spm_new = pickle.load(handle)
with open(data_DIR +'dfn_old_sei_1cycle_vars_Cb5.pickle', 'rb') as handle:
        dfn_old = pickle.load(handle)
with open(data_DIR +'dfn_new_sei_1cycle_vars_Cb5.pickle', 'rb') as handle:
        dfn_new = pickle.load(handle)

# %%
fig, ax = plt.subplots(2,2,figsize=(10,8))
ax1 = ax.flat[0]
ax1.plot(spm_old[1],spm_old[2],'b')
ax1.plot(spm_new[1],spm_new[2],'r--')
ax1.set_xlabel("Time [h]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("Voltage")
ax1.legend(["Old","New"])
ax2 = ax.flat[1]
ax2.plot(spm_old[1],spm_old[19],'b')
ax2.plot(spm_new[1],spm_new[19],'r--')
ax2.set_xlabel("Time [h]")
ax2.set_ylabel(r"$j_\mathrm{SEI}$ [A/m$^2$]")
ax2.set_title("SEI Current Density")
ax3 = ax.flat[2]
ax3.plot(spm_old[1],spm_old[18],'b')
ax3.plot(spm_new[1],spm_new[18],'r--')
ax3.set_xlabel("Time [h]")
ax3.set_title(r"$\delta_\mathrm{SEI}$")
ax3.set_title("SEI Thickness")
ax4 = ax.flat[3]
ax4.plot(spm_old[1],spm_old[17],'b')
ax4.plot(spm_new[1],spm_new[17],'r--')
ax4.set_xlabel("Time [h]")
ax4.set_title(r"$n_\mathrm{Li,Loss}$ [mol]")
ax4.set_title("Lithium Loss")
fig.suptitle("SPM Old vs New")
fig.tight_layout()
fig.savefig(fig_DIR+"spm_comp_sei_1cycle.png",dpi=600)

# %%
fig, ax = plt.subplots(2,2,figsize=(10,8))
ax1 = ax.flat[0]
ax1.plot(dfn_old[1],dfn_old[2],'b')
ax1.plot(dfn_new[1],dfn_new[2],'r--')
ax1.set_xlabel("Time [h]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("Voltage")
ax1.legend(["Old","New"])
ax2 = ax.flat[1]
ax2.plot(dfn_old[1],dfn_old[19],'b')
ax2.plot(dfn_new[1],dfn_new[19],'r--')
ax2.set_xlabel("Time [h]")
ax2.set_ylabel(r"$j_\mathrm{SEI}$ [A/m$^2$]")
ax2.set_title("SEI Current Density")
ax3 = ax.flat[2]
ax3.plot(dfn_old[1],dfn_old[18],'b')
ax3.plot(dfn_new[1],dfn_new[18],'r--')
ax3.set_xlabel("Time [h]")
ax3.set_title(r"$\delta_\mathrm{SEI}$")
ax3.set_title("SEI Thickness")
ax4 = ax.flat[3]
ax4.plot(dfn_old[1],dfn_old[17],'b')
ax4.plot(dfn_new[1],dfn_new[17],'r--')
ax4.set_xlabel("Time [h]")
ax4.set_title(r"$n_\mathrm{Li,Loss}$ [mol]")
ax4.set_title("Lithium Loss")
fig.suptitle("DFN Old vs New")
fig.tight_layout()
fig.savefig(fig_DIR+"dfn_comp_sei_1cycle.png",dpi=600)

# %% [markdown]
# ## SEI 100 Cycles

# %%
with open(data_DIR +'spm_old_sei_100cycle_vars_Cb5.pickle', 'rb') as handle:
        spm_old = pickle.load(handle)
with open(data_DIR +'spm_new_sei_100cycle_vars_Cb5.pickle', 'rb') as handle:
        spm_new = pickle.load(handle)
with open(data_DIR +'dfn_old_sei_100cycle_vars_Cb5.pickle', 'rb') as handle:
        dfn_old = pickle.load(handle)
with open(data_DIR +'dfn_new_sei_100cycle_vars_Cb5.pickle', 'rb') as handle:
        dfn_new = pickle.load(handle)

# %%
fig, ax = plt.subplots(2,2,figsize=(10,8))
ax1 = ax.flat[0]
ax1.plot(spm_old["Cycle number"]/3,spm_old["Capacity [A.h]"],'b')
ax1.plot(spm_new["Cycle number"]/3,spm_new["Capacity [A.h]"],'r--')
ax1.set_xlabel("Cycle Number")
ax1.set_ylabel("Capacity [Ah]")
ax1.set_title("Capacity")
ax1.legend(["Old","New"])
ax2 = ax.flat[1]
ax2.plot(spm_old["Cycle number"]/3,spm_old["Loss of lithium to SEI [mol]"],'b')
ax2.plot(spm_new["Cycle number"]/3,spm_new["Loss of lithium to negative SEI [mol]"],'r--')
ax2.set_xlabel("Cycle Number")
ax2.set_ylabel("Lithium Loss [mol]")
ax2.set_title("Loss of Lithium to SEI")
ax3 = ax.flat[2]
ax3.plot(spm_old["Cycle number"]/3,spm_old["x_100"],'b')
ax3.plot(spm_new["Cycle number"]/3,spm_new["x_100"],'r--')
ax3.set_xlabel("Cycle Number")
ax3.set_ylabel(r"$x_{100}$")
ax3.set_title(r"$x_{100}$")
ax4 = ax.flat[3]
ax4.plot(spm_old["Cycle number"]/3,spm_old["y_0"],'b')
ax4.plot(spm_new["Cycle number"]/3,spm_new["y_0"],'r--')
ax4.set_xlabel("Cycle Number")
ax4.set_ylabel(r"$y_{0}$")
ax4.set_title(r"$y_{0}$")
fig.suptitle("SPM Old vs New")
fig.tight_layout()
fig.savefig(fig_DIR+"spm_comp_sei_100cycle.png",dpi=600)

# %%
fig, ax = plt.subplots(2,2,figsize=(10,8))
ax1 = ax.flat[0]
ax1.plot(dfn_old["Cycle number"]/3,dfn_old["Capacity [A.h]"],'b')
ax1.plot(dfn_new["Cycle number"]/3,dfn_new["Capacity [A.h]"],'r--')
ax1.set_xlabel("Cycle Number")
ax1.set_ylabel("Capacity [Ah]")
ax1.set_title("Capacity")
ax1.legend(["Old","New"])
ax2 = ax.flat[1]
ax2.plot(dfn_old["Cycle number"]/3,dfn_old["Loss of lithium to SEI [mol]"],'b')
ax2.plot(dfn_new["Cycle number"]/3,dfn_new["Loss of lithium to negative SEI [mol]"],'r--')
ax2.set_xlabel("Cycle Number")
ax2.set_ylabel("Lithium Loss [mol]")
ax2.set_title("Loss of Lithium to SEI")
ax3 = ax.flat[2]
ax3.plot(dfn_old["Cycle number"]/3,dfn_old["x_100"],'b')
ax3.plot(dfn_new["Cycle number"]/3,dfn_new["x_100"],'r--')
ax3.set_xlabel("Cycle Number")
ax3.set_ylabel(r"$x_{100}$")
ax3.set_title(r"$x_{100}$")
ax4 = ax.flat[3]
ax4.plot(dfn_old["Cycle number"]/3,dfn_old["y_0"],'b')
ax4.plot(dfn_new["Cycle number"]/3,dfn_new["y_0"],'r--')
ax4.set_xlabel("Cycle Number")
ax4.set_ylabel(r"$y_{0}$")
ax4.set_title(r"$y_{0}$")
fig.suptitle("DFN Old vs New")
fig.tight_layout()
fig.savefig(fig_DIR+"dfn_comp_sei_100cycle.png",dpi=600)

# %%
fig, ax = plt.subplots(2,2,figsize=(10,8))
ax1 = ax.flat[0]
ax1.plot(spm_new["Cycle number"]/3,spm_new["Capacity [A.h]"],'b')
ax1.plot(dfn_new["Cycle number"]/3,dfn_new["Capacity [A.h]"],'r--')
ax1.set_xlabel("Cycle Number")
ax1.set_ylabel("Capacity [Ah]")
ax1.set_title("Capacity")
ax1.legend(["SPM","DFN"])
ax2 = ax.flat[1]
ax2.plot(spm_new["Cycle number"]/3,spm_new["Loss of lithium to negative SEI [mol]"],'b')
ax2.plot(dfn_new["Cycle number"]/3,dfn_new["Loss of lithium to negative SEI [mol]"],'r--')
ax2.set_xlabel("Cycle Number")
ax2.set_ylabel("Lithium Loss [mol]")
ax2.set_title("Loss of Lithium to SEI")
ax3 = ax.flat[2]
ax3.plot(spm_new["Cycle number"]/3,spm_new["x_100"],'b')
ax3.plot(dfn_new["Cycle number"]/3,dfn_new["x_100"],'r--')
ax3.set_xlabel("Cycle Number")
ax3.set_ylabel(r"$x_{100}$")
ax3.set_title(r"$x_{100}$")
ax4 = ax.flat[3]
ax4.plot(spm_new["Cycle number"]/3,spm_new["y_0"],'b')
ax4.plot(dfn_new["Cycle number"]/3,dfn_new["y_0"],'r--')
ax4.set_xlabel("Cycle Number")
ax4.set_ylabel(r"$y_{0}$")
ax4.set_title(r"$y_{0}$")
fig.suptitle("SPM vs DFN")
fig.tight_layout()
fig.savefig(fig_DIR+"spm_dfn_comp_sei_100cycle.png",dpi=600)
